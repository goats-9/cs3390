# %% [markdown]
# # Perform exploratory data analysis and plots time taken against different days for each of meal type
#
# ### Authors
#
# | Name | Roll Number |
# | - | - |
# | Gautam Singh | CS21BTECH11018 |
# | Jaswanth Beere | BM21BTECH11007 |
#
# This `.ipynb` file perform an exploratory data analysis and plots time taken against different days for each of meal type.

# %% [markdown]
# ## Package Imports
#
# The required packages for the prediction are specified here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Datasets
#
# The `pandas` library is used to load the `csv` files.

# %%
df = pd.read_csv("../data/Meal Durations.csv")

# %%
df
# Out:
#     day  start_time  is_holiday  meal_type  location  busy_after  hunger  \
# 0     4         642           0          0         0           1       3
# 1     4         801           0          1         0           1       2
# 2     4        1201           0          2         1           1       1
# 3     4        1304           0          3         1           0       2
# 4     4        1805           0          4         0           1       1
# ..  ...         ...         ...        ...       ...         ...     ...
# 79    3         832           0          1         0           1       2
# 80    3        1024           0          2         1           1       2
# 81    3        1326           0          3         1           1       2
# 82    3        1523           0          4         0           1       2
# 83    3        1744           0          5         0           1       1
#
#     num_courses  meal_duration
# 0             1             12
# 1             1             16
# 2             1              9
# 3             3             43
# 4             1             15
# ..          ...            ...
# 79            2             40
# 80            1              3
# 81            3             22
# 82            1             20
# 83            2             14
#
# [84 rows x 9 columns]

# %%
hunger_meanings = ["not hungry", "slightly hungry", "routine hunger", "very hungry"]
location_meanings = ["at home", "at college", "elsewhere"]
meal_type_meanings = ["morning", "breakfast", "mid-morning", "lunch", "evening", "dinner", "emergency"]
day_meanings = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]

# %%
df.head()
# Out:
#    day  start_time  is_holiday  meal_type  location  busy_after  hunger  \
# 0    4         642           0          0         0           1       3
# 1    4         801           0          1         0           1       2
# 2    4        1201           0          2         1           1       1
# 3    4        1304           0          3         1           0       2
# 4    4        1805           0          4         0           1       1
#
#    num_courses  meal_duration
# 0            1             12
# 1            1             16
# 2            1              9
# 3            3             43
# 4            1             15

# %%
df.columns
# Out:
# Index(['day', 'start_time', 'is_holiday', 'meal_type', 'location',
#        'busy_after', 'hunger', 'num_courses', 'meal_duration'],
#       dtype='object')

# %%
df.sort_values("day", inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#     day  start_time  is_holiday  meal_type  location  busy_after  hunger  \
# 0     0        1102           0          2         1           1       2
# 1     0        1132           1          2         0           0       2
# 2     0        1307           1          3         0           0       2
# 3     0        1541           1          4         0           0       1
# 4     0        1902           0          5         0           1       3
# ..  ...         ...         ...        ...       ...         ...     ...
# 79    6        1305           1          3         0           0       1
# 80    6        1245           1          2         0           0       3
# 81    6         849           1          1         0           0       3
# 82    6         720           1          0         0           0       3
# 83    6        1225           1          2         0           0       1
#
#     num_courses  meal_duration
# 0             1             18
# 1             1             21
# 2             2             33
# 3             1              6
# 4             2             24
# ..          ...            ...
# 79            2             38
# 80            1             13
# 81            2             32
# 82            1             14
# 83            1             23
#
# [84 rows x 9 columns]

# %%
plt.figure(figsize=(10, 5))
for meal_type in range(6):
    # Filter data for the specific meal type
    filtered_data = [df['meal_duration'][i] for i in range(len(df['meal_type'])) if df['meal_type'][i] == meal_type]
    days = [day_meanings[df['day'][i]] for i in range(len(df['meal_type'])) if df['meal_type'][i] == meal_type]
  
    # Plotting
    plt.scatter(days, filtered_data, label=f"Meal Type in a day: {meal_type_meanings[meal_type]}")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.xlabel('Days in a week')
plt.ylabel('Meal Duration ( minutes )')
plt.xticks(rotation='vertical')
plt.title("Meal Duration against different days for each of meal type", pad=20)
plt.tight_layout()
plt.show()
